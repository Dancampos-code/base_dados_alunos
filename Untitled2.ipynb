# %% [markdown]
# <a href="https://colab.research.google.com/github/Dancampos-code/base_dados_alunos/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ! git clone + Url

# !git clone https://github.com/Dancampos-code/base_dados_alunos.git

baseDados = "/content/base_dados_alunos/github - Página1.csv"

with open(baseDados, "r") as arquivo:
  qtd_linhas = arquivo.readlines()
print(len(qtd_linhas))
# Out:
# fatal: destination path 'base_dados_alunos' already exists and is not an empty directory.
# 53
